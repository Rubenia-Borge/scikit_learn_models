# %%
import pandas as pd

penguin_census = pd.read_csv("../input/penguins/penguins_classification.csv")

# %%
penguin_census.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %%
penguin_census.tail()
# Out:
#      Culmen Length (mm)  Culmen Depth (mm)    Species
# 337                55.8               19.8  Chinstrap
# 338                43.5               18.1  Chinstrap
# 339                49.6               18.2  Chinstrap
# 340                50.8               19.0  Chinstrap
# 341                50.2               18.7  Chinstrap

# %%
penguin_census["Species"].value_counts()
# Out:
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: Species, dtype: int64

# %%
_ = penguin_census.hist(figsize=(17, 12))

# %%
import seaborn as sns


n_samples_to_plot = 20
target_column = "Species"
columns = ["Culmen Length (mm)", "Culmen Depth (mm)"]
_ = sns.pairplot(
    data=penguin_census[:n_samples_to_plot],
    vars=columns,
    hue=target_column,
    plot_kws={"alpha": 0.2},
    height=3,
    diag_kind="hist",
    diag_kws={"bins": 30},
)

# %%
# solution
import seaborn

pairplot_figure = seaborn.pairplot(penguin_census, hue="Species")

# %%
pairplot_figure = seaborn.pairplot(penguin_census, hue="Species", height=4)
